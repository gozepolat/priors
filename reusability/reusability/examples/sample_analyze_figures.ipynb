# %%
# %load_ext autoreload
# %autoreload 2

# %%
cd ../..

# %% [raw]
# !pip install -e .

# %%
from IPython.display import Image
from reusability.analysis.stat_summary import summarize_stats

# %%
import math

# %% [markdown]
# ## Comparing graphs (figure 2a vs figure 2b)

# %%
keys = {'shannon', 'expected_spread', 'total_surprisal',
        'num_weight_nodes', 'num_params', 'total_surprisal_based_perf_est',
        'exp_spread_based_perf_est'}

# %%
Image(filename='reusability/figures/figure2a_parameter_efficiency.png')

# %%
fig2a_stats = {'y_w1':1,
               'y_w2':1,
               'y_w3':1,
               'y_w4':1,
               'y_w5':1,
               'y_w6':1,
               'y_w7':1,
               'y_w8':1,
               'y_w9':0,
               'y_w10':0,
               'y_w11':0,
               'y_w12':0,
              }

analysis = summarize_stats(fig2a_stats,
                image_width=1,
                image_height=1,
                num_input_channels=2,
                num_output_nodes=1,
                depth=3, width=2)

{k:v for k,v in analysis.items() if k in keys}
# Out:
# WARNING! Skipping weight item y_w9 since its count is 0
# WARNING! Skipping weight item y_w10 since its count is 0
# WARNING! Skipping weight item y_w11 since its count is 0
# WARNING! Skipping weight item y_w12 since its count is 0
# {'shannon': 3.0,
#  'expected_spread': 0.0,
#  'total_surprisal': 24.0,
#  'num_weight_nodes': 8,
#  'num_params': 8,
#  'total_surprisal_based_perf_est': 2.1255308820838588,
#  'exp_spread_based_perf_est': 0.5405683813627028}

# %%
Image(filename='reusability/figures/figure2b_parameter_efficiency.png')

# %%
fig2b_stats = {'y_w1':2,
               'y_w2':1,
               'y_w3':1,
               'y_w4':2,
               'y_w5':1,
               'y_w6':1,
               'y_w7':1,
               'y_w8':1,
               'y_w9':0,
               'y_w10':0,
               'y_w11':0,
               'y_w12':0,
              }

analysis = summarize_stats(fig2b_stats,
                image_width=1,
                image_height=1,
                num_input_channels=2,
                num_output_nodes=1,
                depth=3, width=2)

{k:v for k,v in analysis.items() if k in keys}
# Out:
# WARNING! Skipping weight item y_w9 since its count is 0
# WARNING! Skipping weight item y_w10 since its count is 0
# WARNING! Skipping weight item y_w11 since its count is 0
# WARNING! Skipping weight item y_w12 since its count is 0
# {'shannon': 2.9219280948873623,
#  'expected_spread': 0.4,
#  'total_surprisal': 24.575424759098897,
#  'num_weight_nodes': 8,
#  'num_params': 8,
#  'total_surprisal_based_perf_est': 2.1597128284232356,
#  'exp_spread_based_perf_est': 1.0259952085329445}

# %%
Image(filename='reusability/figures/figure3a_horizontal_unrolling.png')

# %%
fig3a_stats = {'y_w1':2,
               'y_w2':2,
               'y_w3':2,
               'y_w4':2,
               'y_w5':1,
               'y_w6':1,
               'y_w7':1,
               'y_w8':1,
               'y_w9':0,
               'y_w10':0,
               'y_w11':0,
               'y_w12':0,
              }

analysis = summarize_stats(fig3a_stats,
                image_width=1,
                image_height=1,
                num_input_channels=2,
                num_output_nodes=1,
                depth=3, width=2)

{k:v for k,v in analysis.items() if k in keys}
# Out:
# WARNING! Skipping weight item y_w9 since its count is 0
# WARNING! Skipping weight item y_w10 since its count is 0
# WARNING! Skipping weight item y_w11 since its count is 0
# WARNING! Skipping weight item y_w12 since its count is 0
# {'shannon': 2.9182958340544896,
#  'expected_spread': 0.6666666666666666,
#  'total_surprisal': 24.67970000576925,
#  'num_weight_nodes': 8,
#  'num_params': 8,
#  'total_surprisal_based_perf_est': 2.1658213341563815,
#  'exp_spread_based_perf_est': 1.277533975528909}
